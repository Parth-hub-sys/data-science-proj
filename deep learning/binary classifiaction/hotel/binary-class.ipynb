# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

# %%
hotel = pd.read_csv("./hotel.csv")
hotel.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]

# %%
X = hotel.copy()
y = X.pop('is_canceled')

# %%
X.head()
# Out:
#           hotel  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel        342               2015               July
# 1  Resort Hotel        737               2015               July
# 2  Resort Hotel          7               2015               July
# 3  Resort Hotel         13               2015               July
# 4  Resort Hotel         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  ...  \
# 0                        0                     0       2       0.0  ...
# 1                        0                     0       2       0.0  ...
# 2                        0                     1       1       0.0  ...
# 3                        0                     1       1       0.0  ...
# 4                        0                     2       2       0.0  ...
#
#    deposit_type  agent company days_in_waiting_list customer_type   adr  \
# 0    No Deposit    NaN     NaN                    0     Transient   0.0
# 1    No Deposit    NaN     NaN                    0     Transient   0.0
# 2    No Deposit    NaN     NaN                    0     Transient  75.0
# 3    No Deposit  304.0     NaN                    0     Transient  75.0
# 4    No Deposit  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests reservation_status  \
# 0                            0                          0          Check-Out
# 1                            0                          0          Check-Out
# 2                            0                          0          Check-Out
# 3                            0                          0          Check-Out
# 4                            0                          1          Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 31 columns]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: is_canceled, dtype: int64

# %%
X['arrival_date_month'] = \
    X['arrival_date_month'].map({
        'january' : 1,
        'february' : 2,
        'march' : 3,
        'april' : 4,
        'may' : 5,
        'june' : 6,
        'july' : 7,
        'august' : 8,
        'september' : 9,
        'october' : 10,
        'november' : 11,
        'december' : 12
    })

# %%
features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

# %%
transfer_num = make_pipeline(
    SimpleImputer(strategy = "constant"),
    StandardScaler(),
)
transfer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown="ignore"),
)

# %%
preprocessor = make_column_transformer(
    (transfer_num,features_num),
    (transfer_cat,features_cat),
)

X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.75,stratify=y)
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

input_shape = [X_train.shape[1]]

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid'),
])

# %%
model.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy'],
)

# %%
es = keras.callbacks.EarlyStopping(
    patience = 5,
    min_delta = 0.001,
    restore_best_weights = True,
)

history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=512,
    callbacks=[es],
   
)

history_df = pd.DataFrame(history.history)
history_df.loc[:,['loss','val_loss']].plot(title="crossentropy loss")
history_df.loc[:,['accuracy','val_accuracy']].plot(title="accuracy")
# Out:
# Epoch 1/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7459 - loss: 0.5271 - val_accuracy: 0.8128 - val_loss: 0.4413
# Epoch 2/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.7992 - loss: 0.4294 - val_accuracy: 0.8157 - val_loss: 0.4014
# Epoch 3/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8058 - loss: 0.4170 - val_accuracy: 0.8155 - val_loss: 0.3982
# Epoch 4/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8109 - loss: 0.4062 - val_accuracy: 0.8197 - val_loss: 0.3909
# Epoch 5/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8146 - loss: 0.4010 - val_accuracy: 0.8196 - val_loss: 0.3906
# Epoch 6/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8178 - loss: 0.3946 - val_accuracy: 0.8211 - val_loss: 0.3838
# Epoch 7/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8144 - loss: 0.3951 - val_accuracy: 0.8224 - val_loss: 0.3841
# Epoch 8/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8185 - loss: 0.3922 - val_accuracy: 0.8240 - val_loss: 0.3783
# Epoch 9/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8205 - loss: 0.3888 - val_accuracy: 0.8237 - val_loss: 0.3790
# Epoch 10/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8225 - loss: 0.3870 - val_accuracy: 0.8261 - val_loss: 0.3760
# Epoch 11/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8228 - loss: 0.3829 - val_accuracy: 0.8231 - val_loss: 0.3789
# Epoch 12/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8221 - loss: 0.3841 - val_accuracy: 0.8277 - val_loss: 0.3757
# Epoch 13/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8251 - loss: 0.3798 - val_accuracy: 0.8272 - val_loss: 0.3730
# Epoch 14/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8265 - loss: 0.3773 - val_accuracy: 0.8294 - val_loss: 0.3720
# Epoch 15/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8275 - loss: 0.3749 - val_accuracy: 0.8321 - val_loss: 0.3679
# Epoch 16/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8272 - loss: 0.3757 - val_accuracy: 0.8312 - val_loss: 0.3674
# Epoch 17/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8273 - loss: 0.3729 - val_accuracy: 0.8319 - val_loss: 0.3659
# Epoch 18/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8244 - loss: 0.3757 - val_accuracy: 0.8327 - val_loss: 0.3684
# Epoch 19/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8296 - loss: 0.3732 - val_accuracy: 0.8319 - val_loss: 0.3651
# Epoch 20/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8298 - loss: 0.3704 - val_accuracy: 0.8343 - val_loss: 0.3622
# Epoch 21/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8285 - loss: 0.3695 - val_accuracy: 0.8339 - val_loss: 0.3642
# Epoch 22/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8299 - loss: 0.3649 - val_accuracy: 0.8366 - val_loss: 0.3605
# Epoch 23/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8279 - loss: 0.3674 - val_accuracy: 0.8335 - val_loss: 0.3632
# Epoch 24/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8335 - loss: 0.3612 - val_accuracy: 0.8342 - val_loss: 0.3601
# Epoch 25/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8327 - loss: 0.3621 - val_accuracy: 0.8375 - val_loss: 0.3583
# Epoch 26/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8328 - loss: 0.3633 - val_accuracy: 0.8336 - val_loss: 0.3618
# Epoch 27/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8358 - loss: 0.3582 - val_accuracy: 0.8339 - val_loss: 0.3600
# Epoch 28/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8323 - loss: 0.3627 - val_accuracy: 0.8384 - val_loss: 0.3580
# Epoch 29/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8342 - loss: 0.3580 - val_accuracy: 0.8367 - val_loss: 0.3578
# Epoch 30/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8345 - loss: 0.3570 - val_accuracy: 0.8357 - val_loss: 0.3566
# Epoch 31/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8353 - loss: 0.3533 - val_accuracy: 0.8348 - val_loss: 0.3572
# Epoch 32/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8346 - loss: 0.3558 - val_accuracy: 0.8361 - val_loss: 0.3561
# Epoch 33/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8372 - loss: 0.3536 - val_accuracy: 0.8335 - val_loss: 0.3587
# Epoch 34/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8357 - loss: 0.3541 - val_accuracy: 0.8369 - val_loss: 0.3567
# Epoch 35/100
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8353 - loss: 0.3567 - val_accuracy: 0.8348 - val_loss: 0.3586
# <Axes: title={'center': 'accuracy'}>
