# %% [markdown]
# ### analysis of candy

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
c_data = pd.read_csv('./candy.csv', index_col = 'id')
c_data.head()
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0       100 Grand       Yes     No     Yes             No     No
# 1    3 Musketeers       Yes     No      No             No    Yes
# 2       Air Heads        No    Yes      No             No     No
# 3      Almond Joy       Yes     No      No            Yes     No
# 4       Baby Ruth       Yes     No     Yes            Yes    Yes
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 0               Yes   No  Yes       No         0.732         0.860   66.971725
# 1                No   No  Yes       No         0.604         0.511   67.602936
# 2                No   No   No       No         0.906         0.511   52.341465
# 3                No   No  Yes       No         0.465         0.767   50.347546
# 4                No   No  Yes       No         0.604         0.767   56.914547

# %%
c_data.shape
# Out:
# (83, 13)

# %%
c_data['winpercent'].max()
# Out:
# 84.18029

# %%
# Compare '3 Musketeers' and 'Almond Joy' winpercent
c_data.loc[c_data['competitorname'].isin(['3 Musketeers', 'Almond Joy']), ['competitorname', 'winpercent']]
# Out:
#    competitorname  winpercent
# id
# 1    3 Musketeers   67.602936
# 3      Almond Joy   50.347546

# %%
more_popular = '3 Musketeers'

# %%
c_data.loc[(c_data['competitorname'].isin(['Air Heads','Baby Ruth'])),['competitorname', 'sugarpercent']]
# Out:
#    competitorname  sugarpercent
# id
# 2       Air Heads         0.906
# 4       Baby Ruth         0.604

# %%
more_sugar = 'Air Heads'

# %%
sns.scatterplot(data=c_data, x='sugarpercent', y='winpercent')
# Out:
# <Axes: xlabel='sugarpercent', ylabel='winpercent'>

# %%
sns.scatterplot(data=c_data, x='sugarpercent', y='winpercent', hue='competitorname')
# Out:
# <Axes: xlabel='sugarpercent', ylabel='winpercent'>

# %%
sns.regplot(data= c_data, x='sugarpercent', y='winpercent')
# Out:
# <Axes: xlabel='sugarpercent', ylabel='winpercent'>

# %%
sns.scatterplot(data= c_data,x='pricepercent',y = 'winpercent', hue='chocolate')
# Out:
# <Axes: xlabel='pricepercent', ylabel='winpercent'>

# %%
sns.lmplot(data= c_data,x='pricepercent',y = 'winpercent', hue='chocolate')
