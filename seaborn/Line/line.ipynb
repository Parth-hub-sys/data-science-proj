# %% [markdown]
# ### track monthly visitors to ecach museum

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("./museum_visitors.csv", index_col='Date', parse_dates=True)
data.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %%
data.tail()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2018-07-01        23136              4191                     2620
# 2018-08-01        20815              4866                     2409
# 2018-09-01        21020              4956                     2146
# 2018-10-01        19280              4622                     2364
# 2018-11-01        17163              4082                     2385
#
#             America Tropical Interpretive Center
# Date
# 2018-07-01                                  4718
# 2018-08-01                                  3891
# 2018-09-01                                  3180
# 2018-10-01                                  3775
# 2018-11-01                                  4562

# %%
cam_july18 = data.loc['2018-07','Chinese American Museum']
cam_july18
# Out:
# Date
# 2018-07-01    2620
# Name: Chinese American Museum, dtype: int64

# %%
visitors_cam_july18 = 2620

# %%
ad_oct18 = data.loc['2018-10','Avila Adobe']
ad_oct18
# Out:
# Date
# 2018-10-01    19280
# Name: Avila Adobe, dtype: int64

# %%
fr_oct18 = data.loc['2018-10','Firehouse Museum']
fr_oct18
# Out:
# Date
# 2018-10-01    4622
# Name: Firehouse Museum, dtype: int64

# %%
ad_oct18 - fr_oct18
# Out:
# Date
# 2018-10-01    14658
# dtype: int64

# %%
plt.figure(figsize= (12,6))
sns.lineplot(data = data)
# Out:
# <Axes: xlabel='Date'>

# %%
sns.lineplot(data= data['Avila Adobe'], label='Avila Adobe')
# Out:
# <Axes: xlabel='Date', ylabel='Avila Adobe'>
