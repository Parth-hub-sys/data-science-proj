# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
X_full = pd.read_csv('./train.csv', index_col = 'Id')
X_test_full = pd.read_csv('./test.csv', index_col = 'Id')

# %%
X_full.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
X_test_full.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                    ...
# 1461         Lvl    AllPub    Inside  ...         120        0    NaN  MnPrv
# 1462         Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 1463         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 1464         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1465         HLS    AllPub    Inside  ...         144        0    NaN    NaN
#
# ...

# %%
X_full.dropna(axis=0, subset=['SalePrice'], inplace=True)

# %%
y = X_full.SalePrice

# %%
X_full.drop(['SalePrice'], axis = 1, inplace=True)

# %%
X_full.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC Fence  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 2          Lvl    AllPub       FR2  ...           0        0    NaN   NaN
# 3          Lvl    AllPub    Inside  ...           0        0    NaN   NaN
# 4          Lvl    AllPub    Corner  ...           0        0    NaN   NaN
# 5          Lvl    AllPub       FR2  ...           0        0    NaN   NaN
#
#    MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
x = X_full.select_dtypes(exclude=['object'])
x_test = X_test_full.select_dtypes(exclude=['object'])

# %%
X_train,X_valid,y_train,y_valid = train_test_split(x,y,train_size=0.8,test_size=0.2,random_state=0)

# %%
X_train.head()
# Out:
#      MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 619          20         90.0    11694            9            5       2007
# 871          20         60.0     6600            5            5       1962
# 93           30         80.0    13360            5            7       1921
# 818          20          NaN    13265            8            5       2002
# 303          20        118.0    13704            7            5       2001
#
#      YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  GarageArea  \
# Id                                                     ...
# 619          2007       452.0          48           0  ...         774
# 871          1962         0.0           0           0  ...         308
# 93           2006         0.0         713           0  ...         432
# 818          2002       148.0        1218           0  ...         857
# 303          2002       150.0           0           0  ...         843
#
# ...

# %%
X_valid.head()
# Out:
#      MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 530          20          NaN    32668            6            3       1957
# 492          50         79.0     9490            6            7       1941
# 460          50          NaN     7015            5            4       1950
# 280          60         83.0    10005            7            5       1977
# 656         160         21.0     1680            6            5       1971
#
#      YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  GarageArea  \
# Id                                                     ...
# 530          1975         NaN        1219           0  ...         484
# 492          1950         0.0         403         165  ...         240
# 460          1950       161.0         185           0  ...         352
# 280          1977       299.0         392           0  ...         505
# 656          1971       381.0           0           0  ...         264
#
# ...

# %%
y_train.head()
# Out:
# Id
# 619    314813
# 871    109500
# 93     163500
# 818    271000
# 303    205000
# Name: SalePrice, dtype: int64

# %%
y_valid.head()
# Out:
# Id
# 530    200624
# 492    133000
# 460    110000
# 280    192000
# 656     88000
# Name: SalePrice, dtype: int64

# %%
print(X_train.shape)
# Out:
# (1168, 36)

# %%
missing_val_count_by_column = (X_train.isnull().sum())

# %%
print(missing_val_count_by_column[missing_val_count_by_column > 0])
# Out:
# LotFrontage    212
# MasVnrArea       6
# GarageYrBlt     58
# dtype: int64

# %%
total_miss = 212+6+58
total_miss
# Out:
# 276

# %% [markdown]
# ### PART 1

# %% [markdown]
# ### REMOVE MISSING VALUES

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
def socre_dataset(x_train, x_valid, y_train, y_valid):
    model = RandomForestRegressor(n_estimators=100, random_state=0)
    model.fit(x_train,y_train)
    preds = model.predict(x_valid)
    return mean_absolute_error(y_valid,preds)

# %%
cols_with_missing = [col for col in X_train.columns
                     if X_train[col].isnull().any()]

# %%
redused_X_train = X_train.drop(cols_with_missing, axis=1)
reduced_X_valid = X_valid.drop(cols_with_missing, axis=1)

# %%
print('MAE from reduced dataset:')
print(socre_dataset(redused_X_train,reduced_X_valid,y_train,y_valid))
# Out:
# MAE from reduced dataset:
# 17837.82570776256

# %% [markdown]
# ### fill missing values with the mean of each column

# %%
from sklearn.impute import SimpleImputer

# %%
my_imputer = SimpleImputer(strategy='mean')

imputed_X_train = pd.DataFrame(my_imputer.fit_transform(X_train))
imputed_X_valid = pd.DataFrame(my_imputer.transform(X_valid))

imputed_X_train.columns = X_train.columns
imputed_X_valid.columns = X_valid.columns

# %%
print("MAE from imputed dataset:")
print(socre_dataset(imputed_X_train, imputed_X_valid, y_train, y_valid))
# Out:
# MAE from imputed dataset:
# 18062.894611872147

# %%
final_imputer = SimpleImputer(strategy='median')
final_X_train = pd.DataFrame(final_imputer.fit_transform(X_train))
final_X_valid = pd.DataFrame(final_imputer.transform(X_valid))
final_X_train.columns = X_train.columns
final_X_valid.columns = X_valid.columns

# %%
model = RandomForestRegressor(n_estimators=100, random_state=0)
model.fit(final_X_train, y_train)
pred_valid= model.predict(final_X_valid)
print("MAE from final dataset:")
print(mean_absolute_error(y_valid, pred_valid))
# Out:
# MAE from final dataset:
# 17791.59899543379

# %%
final_X_test = pd.DataFrame(final_imputer.transform(x_test))
pred_test = model.predict(final_X_test)
# Out:
# c:\Users\91972\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
output = pd.DataFrame({'ID' :x_test.index,
                       'SalePrice' :pred_test})

output.to_csv('submission.csv', index=False)
